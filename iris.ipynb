# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
 print(np.__version__)
print(pd.__version__)
print(sns.__version__)
import sys
print(sys.version)
# Out:
# 1.18.1
# 1.0.1
# 0.10.0
# 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]

# %%
df = pd.read_csv('data//iris.csv')

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  l. setosa
# 0  4.9  4.6  1.4  0.2  l. setosa
# 1  4.7  5.6  1.5  0.3  l. setosa
# 2  4.6  4.7  1.6  0.3  l. setosa
# 3  5.0  5.2  1.7  0.4  l. setosa
# 4  5.4  4.1  1.9  0.5  l. setosa

# %%
df = pd.read_csv('data//iris.csv', header=None)
df.head()
# Out:
#      0    1    2    3          4
# 0  5.1  3.5  1.4  0.2  l. setosa
# 1  4.9  4.6  1.4  0.2  l. setosa
# 2  4.7  5.6  1.5  0.3  l. setosa
# 3  4.6  4.7  1.6  0.3  l. setosa
# 4  5.0  5.2  1.7  0.4  l. setosa

# %%
col_name = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class' ]

# %%
df.columns = col_name

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width      class
# 0           5.1          3.5           1.4          0.2  l. setosa
# 1           4.9          4.6           1.4          0.2  l. setosa
# 2           4.7          5.6           1.5          0.3  l. setosa
# 3           4.6          4.7           1.6          0.3  l. setosa
# 4           5.0          5.2           1.7          0.4  l. setosa

# %% [markdown]
# ## Iris data from seaborn

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count      6.000000     6.000000      6.000000     6.000000
# mean       4.950000     4.616667      1.583333     0.316667
# std        0.288097     0.752108      0.194079     0.116905
# min        4.600000     3.500000      1.400000     0.200000
# 25%        4.750000     4.225000      1.425000     0.225000
# 50%        4.950000     4.650000      1.550000     0.300000
# 75%        5.075000     5.075000      1.675000     0.375000
# max        5.400000     5.600000      1.900000     0.500000

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# ## Visualisation

# %%
sns.pairplot(iris, hue='species', height=3, aspect=1);

# %%
iris.hist(edgecolor='black', linewidth=1.2, figsize=(12,8));
plt.show()

# %%
plt.figure(figsize=(12,8));
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length', data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width', data=iris)

# %%
 iris.boxplot(by='species', figsize=(12,8));

# %%
pd.plotting.scatter_matrix(iris, figsize=(12,10))
plt.show()

# %%
sns.pairplot(iris, hue='species', diag_kind='kde');
